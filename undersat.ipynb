# %%
# %pip install understatapi pandas --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import understatapi

client = understatapi.UnderstatClient()

# %%
league_data = client.league(league ='EPL').get_match_data(season='2024')

# %%
league_data[0]
# Out:
# {'id': '26602',
#  'isResult': True,
#  'h': {'id': '89', 'title': 'Manchester United', 'short_title': 'MUN'},
#  'a': {'id': '228', 'title': 'Fulham', 'short_title': 'FLH'},
#  'goals': {'h': '1', 'a': '0'},
#  'xG': {'h': '2.04268', 'a': '0.418711'},
#  'datetime': '2024-08-16 19:00:00',
#  'forecast': {'w': '0.8069', 'd': '0.1489', 'l': '0.0442'}}

# %%
shot_data = client.match(match='26602').get_shot_data()
shot_data
# Out:
# {'h': [{'id': '584630',
#    'minute': '19',
#    'result': 'MissedShots',
#    'X': '0.970999984741211',
#    'Y': '0.6730000305175782',
#    'xG': '0.050078392028808594',
#    'player': 'Bruno Fernandes',
#    'h_a': 'h',
#    'player_id': '1228',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26602',
#    'h_team': 'Manchester United',
#    'a_team': 'Fulham',
#    'h_goals': '1',
#    'a_goals': '0',
#    'date': '2024-08-16 19:00:00',
#    'player_assisted': 'Lisandro Martínez',
#    'lastAction': 'Chipped'},
#   {'id': '584631',
#    'minute': '26',
#    'result': 'MissedShots',
#    'X': '0.7469999694824219',
#    'Y': '0.47900001525878905',
#    'xG': '0.020807035267353058',
#    'player': 'Casemiro',
#    'h_a': 'h',
#    'player_id': '2248',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26602',
#    'h_team': 'Manchester United',
#    'a_team': 'Fulham',
# ...

# %%
player_data = client.player(player='10552').get_shot_data()
player_data
# Out:
# [{'id': '498585',
#   'minute': '33',
#   'result': 'SavedShot',
#   'X': '0.9330000305175781',
#   'Y': '0.6630000305175782',
#   'xG': '0.07541359961032867',
#   'player': 'Alejandro Garnacho',
#   'h_a': 'a',
#   'player_id': '10552',
#   'situation': 'OpenPlay',
#   'season': '2022',
#   'shotType': 'LeftFoot',
#   'match_id': '18342',
#   'h_team': 'Aston Villa',
#   'a_team': 'Manchester United',
#   'h_goals': '3',
#   'a_goals': '1',
#   'date': '2022-11-06 14:00:00',
#   'player_assisted': 'Christian Eriksen',
#   'lastAction': 'Pass'},
#  {'id': '500840',
#   'minute': '92',
#   'result': 'Goal',
#   'X': '0.924000015258789',
#   'Y': '0.624000015258789',
#   'xG': '0.3428359925746918',
#   'player': 'Alejandro Garnacho',
#   'h_a': 'a',
#   'player_id': '10552',
#   'situation': 'OpenPlay',
#   'season': '2022',
#   'shotType': 'LeftFoot',
#   'match_id': '18354',
#   'h_team': 'Fulham',
#   'a_team': 'Manchester United',
#   'h_goals': '1',
#   'a_goals': '2',
# ...

# %%
df = pd.DataFrame(player_data)
df.head()
# df.tail()
# df.info()
# df.describe()
# df.columns
# df.index
# df.shape
# df.size
# Out:
#        id minute       result                   X                   Y  \
# 0  498585     33    SavedShot  0.9330000305175781  0.6630000305175782
# 1  500840     92         Goal   0.924000015258789   0.624000015258789
# 2  501630      5  MissedShots  0.7919999694824219   0.500999984741211
# 3  501631     16    SavedShot               0.875  0.5929999923706055
# 4  502236     73  BlockedShot   0.799000015258789  0.7340000152587891
#
#                      xG              player h_a player_id   situation season  \
# 0   0.07541359961032867  Alejandro Garnacho   a     10552    OpenPlay   2022
# 1    0.3428359925746918  Alejandro Garnacho   a     10552    OpenPlay   2022
# 2  0.027302099391818047  Alejandro Garnacho   a     10552  FromCorner   2022
# 3   0.34724900126457214  Alejandro Garnacho   a     10552    OpenPlay   2022
# 4  0.035613201558589935  Alejandro Garnacho   h     10552    OpenPlay   2022
#
#     shotType match_id                   h_team             a_team h_goals  \
# ...
